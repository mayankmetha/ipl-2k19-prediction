# %%
import os
import pandas as pd
import numpy as np

# %%
bat = pd.read_csv(os.getcwd()+'/../out/clustering/bowl.csv',header=None,delimiter=':')

g = bat.groupby(1)

for x in g:
    print(x)
# Out:
# (0,                        0  1
# 0               MS Dhoni  0
# 2           Sam Billings  0
# 3      Chaitanya Bishnoi  0
# 7        Ruturaj Gaikwad  0
# 11          Kedar Jadhav  0
# 12    Narayan Jagadeesan  0
# 13            Monu Kumar  0
# 20          Dhruv Shorey  0
# 26       Bandaru Ayyappa  0
# 27          Ankush Bains  0
# 30          Colin Ingram  0
# 31          Shreyas Iyer  0
# 33          Manjot Kalra  0
# 37          Rishabh Pant  0
# 42   Sherfane Rutherford  0
# 43          Jalaj Saxena  0
# 45          Prithvi Shaw  0
# 49        Mayank Agarwal  0
# 50        Arshdeep Singh  0
# 53       Agnivesh Ayachi  0
# 56         Harpreet Brar  0
# 58         Sarfaraz Khan  0
# 60          David Miller  0
# 63            Karun Nair  0
# 64      Darshan Nalkande  0
# 65       Nicholas Pooran  0
# 66          Lokesh Rahul  0
# 68          Simran Singh  0
# 72        Dinesh Karthik  0
# 76             Joe Denly  0
# ..                   ... ..
# 114          Aditya Tare  0
# ...
