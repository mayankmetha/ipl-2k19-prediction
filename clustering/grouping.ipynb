# %%
import os
import pandas as pd
import numpy as np

# %%
bat = pd.read_csv(os.getcwd()+'/../out/clustering/bat.csv',header=None,delimiter=':')

g = bat.groupby(1)

for x in g:
    print(x)
# Out:
# (0,                        0  1
# 9            Imran Tahir  0
# 19          Mohit Sharma  0
# 20          Dhruv Shorey  0
# 34           Amit Mishra  0
# 41         Kagiso Rabada  0
# 44         Ishant Sharma  0
# 48         Hanuma Vihari  0
# 52   Ravichandran Ashwin  0
# 61        Mohammed Shami  0
# 65       Nicholas Pooran  0
# 74           KC Cariappa  0
# 77       Lockie Ferguson  0
# 79         Kuldeep Yadav  0
# 90           Rinku Singh  0
# 96        Jasprit Bumrah  0
# 106       Lasith Malinga  0
# 107      Mayank Markande  0
# 119          Varun Aaron  0
# 125        Shreyas Gopal  0
# 127      Dhawal Kulkarni  0
# 129       Mahipal Lomror  0
# 142       Jaydev Unadkat  0
# 147  Nathan Coulter-Nile  0
# 150          Shivam Dube  0
# 157       Mohammed Siraj  0
# 161    Prayas Ray Barman  0
# 166          Umesh Yadav  0
# 171         Basil Thampi  0
# 173    Shreevats Goswami  0
# 177    Bhuvneshwar Kumar  0)
# (1,                      0  1
# 0             MS Dhoni  1
# ...
