# %%
import os
import pandas as pd
import numpy as np

# %%
print([ _ for _ in pd.read_csv(os.getcwd()+'/../out/clustering/bat.csv',header=None,delimiter=':').groupby(1)])
# Out:
# [(0,                        0  1
# 1                KM Asif  0
# 3      Chaitanya Bishnoi  0
# 7        Ruturaj Gaikwad  0
# 12    Narayan Jagadeesan  0
# 13            Monu Kumar  0
# 14           Lungi Ngidi  0
# 17      Mitchell Santner  0
# 24          David Willey  0
# 26       Bandaru Ayyappa  0
# 27          Ankush Bains  0
# 32    Sandeep Lamichhane  0
# 33          Manjot Kalra  0
# 40            Keemo Paul  0
# 42   Sherfane Rutherford  0
# 43          Jalaj Saxena  0
# 46           Nathu Singh  0
# 50        Arshdeep Singh  0
# 51        Murugan Ashwin  0
# 53       Agnivesh Ayachi  0
# 56         Harpreet Brar  0
# 64      Darshan Nalkande  0
# 68          Simran Singh  0
# 70    Varun Chakravarthy  0
# 71        Hardus Viljoen  0
# 76             Joe Denly  0
# 78          Harry Gurney  0
# 81       Shrikant Mundhe  0
# 84         Anrich Nortje  0
# 85       Prasidh Krishna  0
# 86           Prithvi Raj  0
# 92       Sandeep Warrier  0
# 94      Anmolpreet Singh  0
# ...

# %%
print([ _ for _ in pd.read_csv(os.getcwd()+'/../out/clustering/bowl.csv',header=None,delimiter=':').groupby(1)])
# Out:
# [(0,                        0  1
# 5          Deepak Chahar  0
# 8        Harbhajan Singh  0
# 10       Ravindra Jadeja  0
# 18           Karn Sharma  0
# 19          Mohit Sharma  0
# 21        Shardul Thakur  0
# 23          Shane Watson  0
# 28           Trent Boult  0
# 38            Axar Patel  0
# 39         Harshal Patel  0
# 47         Rahul Tewatia  0
# 51        Murugan Ashwin  0
# 52   Ravichandran Ashwin  0
# 57      Moises Henriques  0
# 70    Varun Chakravarthy  0
# 73     Carlos Brathwaite  0
# 75         Piyush Chawla  0
# 79         Kuldeep Yadav  0
# 88         Andre Russell  0
# 93          Rohit Sharma  0
# 96        Jasprit Bumrah  0
# 108        Hardik Pandya  0
# 109        Krunal Pandya  0
# 110       Kieron Pollard  0
# 117         Yuvraj Singh  0
# 119          Varun Aaron  0
# 120         Jofra Archer  0
# 127      Dhawal Kulkarni  0
# 136            Ish Sodhi  0
# 137           Ben Stokes  0
# 142       Jaydev Unadkat  0
# 157       Mohammed Siraj  0
# ...
